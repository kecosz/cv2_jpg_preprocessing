# %% [markdown]
# <a href="https://colab.research.google.com/github/kecosz/cv2_jpg_preprocessing/blob/main/jpg_cv2_gaussianfilter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/kecosz/cv2_jpg_preprocessing.git
# Out:
# Cloning into 'cv2_jpg_preprocessing'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 16 (delta 3), reused 8 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (16/16), 712.32 KiB | 5.44 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
import numpy as np
import matplotlib.pyplot as plt
#from keras.preprocessing import image
#from keras.preprocessing.image import ImageDataGenerator,array_to_img,img_to_array
import cv2
from google.colab.patches import cv2_imshow

import glob
files = glob.glob("cv2_jpg_preprocessing/data/jpg111523/*") #set sample file folder
files
# Out:
# ['cv2_jpg_preprocessing/data/jpg111523/z2.jpg',
#  'cv2_jpg_preprocessing/data/jpg111523/z4.jpg',
#  'cv2_jpg_preprocessing/data/jpg111523/z1.jpg',
#  'cv2_jpg_preprocessing/data/jpg111523/z3.jpg']

# %%
im_gauss_s = []
for n,i in enumerate(files):
  im = cv2.imread(i)
  im_gauss = cv2.GaussianBlur(im, (5, 5), 50) #set parameters
  imgs = cv2.hconcat([im, im_gauss])
  cv2_imshow(imgs)
  im_gauss_s.append(im_gauss)
# Out:
# <PIL.Image.Image image mode=RGB size=624x234>
# <PIL.Image.Image image mode=RGB size=626x235>
# <PIL.Image.Image image mode=RGB size=624x235>
# <PIL.Image.Image image mode=RGB size=624x235>
